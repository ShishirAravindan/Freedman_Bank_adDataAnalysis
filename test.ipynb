# %%
# %pip install transformers

# %%
import torch
from transformers import BertTokenizer, BertModel
import matplotlib.pyplot as plt

# Loading the pre-trained model's tokenizer (a.k.a dictionary)
model_names = {'base uncased': 'bert-base-uncased', 'large uncased': 'bert-large-uncased', 
               'base cased': 'bert-base-cased', 'large cased': 'bert-large-cased'}
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased')

# %%
from Scripts import createTokensFromAd
ads_tokenized_text = createTokensFromAd.main()
tokenized_ads_text={}
tokenized_ads_index = {}
tokenized_ads_segments = {}
for identifier, marked_text in ads_tokenized_text.items():
    tokenized_ads_text[identifier] = tokenizer.tokenize(marked_text)

    # Map the token strings to their vocabulary indeces.
    tokenized_ads_index[identifier] = tokenizer.convert_tokens_to_ids(tokenized_ads_text[identifier])

    # Generating segment IDs for the marked text
    tokenized_text = ' '.join(tokenized_ads_text[identifier])
    tokenized_ads_segments[identifier] = createTokensFromAd.getSegmentIDs(tokenized_text)
    print(len(marked_text), len(tokenized_ads_text[identifier]), len(tokenized_ads_index[identifier]), len(tokenized_ads_segments[identifier]))

i = 0
for identifier, indexed_tokens in tokenized_ads_segments.items():
    print(len(tokenized_ads_text[identifier]), len(tokenized_ads_segments[identifier]))
    print("\n")
    if i < 2: i += 1
    else: break

# TODO: Verify Assumption: that index_tokens is generated accurately
# Out:
# 264 58 58 58
# 168 38 38 38
# 282 54 54 54
# 249 51 51 51
# 254 56 56 56
# 257 61 61 61
# 293 65 65 65
# 169 40 40 40
# 237 52 52 52
# 793 171 171 171
# 200 42 42 42
# 335 84 84 84
# 214 42 42 42
# 323 64 64 64
# 417 106 106 106
# 288 61 61 61
# 135 33 33 33
# 318 67 67 67
# 490 106 106 106
# 502 101 101 101
# 452 90 90 90
# 242 55 55 55
# 137 25 25 25
# 300 64 64 64
# 195 44 44 44
# 259 58 58 58
# 250 59 59 59
# 288 63 63 63
# 428 88 88 88
# 428 88 88 88
# 428 88 88 88
# 444 90 90 90
# 444 90 90 90
# 428 88 88 88
# 444 90 90 90
# 428 88 88 88
# 444 90 90 90
# 428 88 88 88
# 673 146 146 146
# 444 90 90 90
# 174 38 38 38
# 690 148 148 148
# 690 148 148 148
# 880 172 172 172
# 487 105 105 105
# 316 62 62 62
# 464 97 97 97
# 880 172 172 172
# 260 50 50 50
# 476 109 109 109
# 322 68 68 68
# 487 105 105 105
# 316 62 62 62
# 476 109 109 109
# 487 105 105 105
# 464 97 97 97
# 254 49 49 49
# 322 68 68 68
# 322 68 68 68
# 260 50 50 50
# 316 62 62 62
# 464 97 97 97
# 487 105 105 105
# ...
